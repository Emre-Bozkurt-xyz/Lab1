# %% [markdown]
# ## You probably want to make a venv + install requirements

# %%
# Run this cell to set up the virtual environment
# !python -m venv .venv
# %pip install -r requirements.txt
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ------------------------------- -------- 1.8/2.3 MB 9.9 MB/s eta 0:00:01
#    ---------------------------------------- 2.3/2.3 MB 9.1 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/8.3 MB ? eta -:--:--
#    ----------- ---------------------------- 2.4/8.3 MB 12.9 MB/s eta 0:00:01
#    -------------------------- ------------- 5.5/8.3 MB 13.9 MB/s eta 0:00:01
#    ---------------------------------------- 8.3/8.3 MB 13.6 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/12.4 MB ? eta -:--:--
#    --------- ------------------------------ 2.9/12.4 MB 14.3 MB/s eta 0:00:01
#    ------------------ --------------------- 5.8/12.4 MB 14.1 MB/s eta 0:00:01
#    ---------------------------- ----------- 8.9/12.4 MB 14.3 MB/s eta 0:00:01
# ...
